# %%
import sys
import pandas as pd
import numpy as np

path_to_datasets = '../../traneyelpdataset/'

yelp_review_df = pd.read_csv(path_to_datasets + 'yelp_review.csv')
yelp_checkin_df = pd.read_csv(path_to_datasets + 'yelp_checkin.csv')
yelp_business_df = pd.read_csv(path_to_datasets + 'yelp_business.csv')
yelp_user_df = pd.read_csv(path_to_datasets + 'yelp_user.csv')
yelp_tip_df = pd.read_csv(path_to_datasets + 'yelp_tip.csv')
yelp_business_hours_df = pd.read_csv(path_to_datasets + 'yelp_business_hours.csv')
yelp_business_attributes_df = pd.read_csv(path_to_datasets + 'yelp_business_attributes.csv')

# %%
yelp_review_df.head(1)
# Out:
#                 review_id                 user_id             business_id  \
# 0  vkVSCC7xljjrAI4UGfnKEQ  bv2nCi5Qv5vroFiqKGopiw  AEx2SYEUJmTxVVB18LlCwA
#
#    stars        date                                               text  \
# 0      5  2016-05-28  Super simple place but amazing nonetheless. It...
#
#    useful  funny  cool
# 0       0      0     0

# %%
yelp_checkin_df.head(1)
# Out:
#               business_id weekday  hour  checkins
# 0  3Mc-LxcqeguOXOVT_2ZtCg     Tue  0:00        12

# %%
yelp_business_df.head(1)
# Out:
#               business_id                name neighborhood  \
# 0  FYWN1wneV18bWNgQjJ2GNg  "Dental by Design"          NaN
#
#                       address       city state postal_code  latitude  \
# 0  "4855 E Warner Rd, Ste B9"  Ahwatukee    AZ       85044  33.33069
#
#     longitude  stars  review_count  is_open  \
# 0 -111.978599    4.0            22        1
#
#                                           categories
# 0  Dentists;General Dentistry;Health & Medical;Or...

# %%
yelp_user_df.head(1)
# Out:
#                   user_id   name  review_count yelping_since  \
# 0  JJ-aSuM4pCFPdkfoZ34q0Q  Chris            10    2013-09-24
#
#                                              friends  useful  funny  cool  \
# 0  0njfJmB-7n84DlIgUByCNw, rFn3Xe3RqHxRSxWOU19Gpg...       0      0     0
#
#    fans elite        ...          compliment_more  compliment_profile  \
# 0     0  None        ...                        0                   0
#
#    compliment_cute  compliment_list  compliment_note  compliment_plain  \
# 0                0                0                0                 0
#
#    compliment_cool  compliment_funny  compliment_writer  compliment_photos
# 0                0                 0                  0                  0
#
# [1 rows x 22 columns]

# %%
yelp_tip_df.head(1)
# Out:
#                                                 text        date  likes  \
# 0  Great breakfast large portions and friendly wa...  2015-08-12      0
#
#               business_id                 user_id
# 0  jH19V2I9fIslnNhDzPmdkA  ZcLKXikTHYOnYt5VYRO5sg

# %%
yelp_business_hours_df.head(1)
# Out:
#               business_id     monday    tuesday  wednesday   thursday  \
# 0  FYWN1wneV18bWNgQjJ2GNg  7:30-17:0  7:30-17:0  7:30-17:0  7:30-17:0
#
#       friday saturday sunday
# 0  7:30-17:0     None   None

# %%
yelp_business_attributes_df.head(1)
# Out:
#               business_id AcceptsInsurance ByAppointmentOnly  \
# 0  FYWN1wneV18bWNgQjJ2GNg               Na                Na
#
#   BusinessAcceptsCreditCards BusinessParking_garage BusinessParking_street  \
# 0                         Na                   True                     Na
#
#   BusinessParking_validated BusinessParking_lot BusinessParking_valet  \
# 0                        Na                  Na                    Na
#
#   HairSpecializesIn_coloring            ...            Corkage  \
# 0                         Na            ...                 Na
#
#   DietaryRestrictions_dairy-free DietaryRestrictions_gluten-free  \
# 0                             Na                              Na
#
#   DietaryRestrictions_vegan DietaryRestrictions_kosher  \
# 0                        Na                         Na
#
#   DietaryRestrictions_halal DietaryRestrictions_soy-free  \
# 0                        Na                           Na
#
# ...
