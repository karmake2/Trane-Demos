# %% [markdown]
# ## Imports and Helper Functions

# %%
RE_RUN_CELLS = False
import sys
#Path to Trane for imports
sys.path.append('/Users/Alexander/Documents/Trane/Trane__HDI_REPO')
path_to_datasets = '../../../Trane__Local_Misc/Formatted Datasets/Yelp Reviews/'
import pandas as pd
import trane
import json
import random
import datetime
import pickle
import featuretools as ft
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model, decomposition, datasets
from sklearn.metrics import accuracy_score
from sklearn import metrics
import scikitplot as skplt

def save_obj(obj, name):
    with open('pickled_objects/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)
def load_obj(name):
    try:
        with open('pickled_objects/' + name + '.pkl', 'rb') as f:
            return pickle.load(f)
    except:
        return None
def generate_probs(entity_id_column,
                            label_generating_column,
                            time_column,
                            table_meta,
                            filter_column,
                            is_pick_random_problems = True):
    generator = trane.PredictionProblemGenerator(table_meta, entity_id_column, label_generating_column, time_column, filter_column)
    probs = []

    all_probs = list(generator.generate())

    if is_pick_random_problems:
        random.shuffle(all_probs)

    for idx, prob in enumerate(all_probs):
        probs.append(prob)
        if idx + 1 == NUM_PROBLEMS_TO_GENERATE:
            break
    prediction_problems_json = trane.prediction_problems_to_json_file(
        probs, table_meta, entity_id_column, label_generating_column, time_column, "prediction_problems.json")

    return probs

def convert(str, format = None):
    return datetime.datetime.strptime(str, format)
def file_to_table_meta(filepath):
    return trane.TableMeta(json.loads(open(filepath).read()))

# %% [markdown]
# ## Load, Format and Sample Data (2 Minutes)

# %%
merged_df = load_obj('merged_df')
sampled_yelp_business_df = load_obj('sampled_yelp_business_df')
sampled_yelp_review_df = load_obj('sampled_yelp_review_df')
sampled_yelp_user_df = load_obj('sampled_yelp_user_df')
sampled_yelp_checkin_df = load_obj('sampled_yelp_checkin_df')

if  (merged_df is None or 
    sampled_yelp_business_df is None or 
    sampled_yelp_review_df is None or 
    sampled_yelp_user_df is None or
    sampled_yelp_checkin_df is None or
    RE_RUN_CELLS):
    
    yelp_review_df = pd.read_csv(path_to_datasets + 'yelp_review.csv')
    yelp_checkin_df = pd.read_csv(path_to_datasets + 'yelp_checkin.csv')
    yelp_business_df = pd.read_csv(path_to_datasets + 'yelp_business.csv')
    yelp_user_df = pd.read_csv(path_to_datasets + 'yelp_user.csv')

    sampled_yelp_review_df = yelp_review_df.head(1000)
    sampled_business_ids = sampled_yelp_review_df['business_id'].unique()
    sampled_user_ids = sampled_yelp_review_df['user_id'].unique()
    sampled_review_ids = sampled_yelp_review_df['review_id'].unique()
    sampled_yelp_checkin_df = yelp_checkin_df[yelp_checkin_df['business_id'].isin(sampled_business_ids)]
    sampled_yelp_business_df = yelp_business_df[yelp_business_df['business_id'].isin(sampled_business_ids)] 
    sampled_yelp_user_df = yelp_user_df[yelp_user_df['user_id'].isin(sampled_user_ids)]

    assert(len(sampled_business_ids) == len(sampled_yelp_business_df))
    assert(len(sampled_user_ids) == len(sampled_yelp_user_df))
    assert(len(sampled_review_ids) == len(sampled_yelp_review_df))

    print("Sampling Reuslts ---")
    print("Number of reviews: {}".format(len(sampled_yelp_review_df)))
    print("Number of businesses: {}".format(len(sampled_business_ids)))
    print("Number of users: {}".format(len(sampled_user_ids)))
    print("Number of checkins: {}".format(len(sampled_yelp_checkin_df)))

    merge_step_1 = pd.merge(sampled_yelp_review_df, sampled_yelp_user_df, how = 'left', on ='user_id')
    merge_step_2 = pd.merge(merge_step_1, sampled_yelp_business_df, how = 'left', on = 'business_id')
    merge_step_3 = pd.merge(merge_step_2, sampled_yelp_checkin_df, how = 'right', on = 'business_id')
    merged_df = merge_step_3
    merged_df['date'] = merged_df['date'].apply(str)
    merged_df['date'] = merged_df['date'].apply(convert, format = '%Y-%m-%d')
    merged_df = merged_df.rename(columns = {'stars_x': 'stars'})

    distinct_business_ids_in_merged_df = merged_df['business_id'].unique()
    #Note merged_df only contains 959 distinct business_ids. Checkins only contains information from 959 businesses.
    #    That's why merged_df only has 959 distinct business_ids, as opposed to the 974 unique business_ids 
    #    contained in the sample_yelp_review_df.
    #Note merged_df contains more than the 78792 unique check-ins because there are multiple reviews for some business_ids so
    #    each unique review_id is matched to a new business_id. There are 1000 review_ids, but only 974 business_ids.
    #
    save_obj(merged_df, 'merged_df')
    save_obj(sampled_yelp_business_df, "sampled_yelp_business_df")
    save_obj(sampled_yelp_review_df, "sampled_yelp_review_df")
    save_obj(sampled_yelp_user_df, "sampled_yelp_user_df")
    save_obj(sampled_yelp_checkin_df, "sampled_yelp_checkin_df")

# %% [markdown]
# ## Constants

# %%
table_meta = file_to_table_meta(path_to_datasets + "meta.json")
entity_id_column = 'business_id'
label_generating_column = 'stars'
time_column = 'date'
filter_column = 'user_id'
NUM_PROBLEMS_TO_GENERATE = 100
prediction_problems_filename = "../JSON Files/yelp_prediction_problems.json"

# %% [markdown]
# ## Generate Prediction Problems

# %%
from trane.core.prediction_problem import select_by_diversity

problems = load_obj('problems')
if (problems is None or
    RE_RUN_CELLS):
    problem_generator_obj = trane.PredictionProblemGenerator(table_meta, entity_id_column, label_generating_column, time_column, filter_column)
    problem_generator = problem_generator_obj.generator(merged_df)
    problems = []
    problems = list(problem_generator)
    trane.prediction_problems_to_json_file(problems, table_meta, 
                                           entity_id_column, label_generating_column, 
                                           time_column, 
                                           prediction_problems_filename)
    
    #append a greater row op to every prediction problem
    greaterRowOp = trane.ops.row_ops.GreaterRowOp(label_generating_column)
    unique_values = set(merged_df[label_generating_column])
    hyper_param = select_by_diversity(unique_values, merged_df, greaterRowOp, label_generating_column)
    greaterRowOp.set_hyper_parameter(hyper_param)
    
    
    save_obj(problems, 'problems')

# %% [markdown]
# ## Generate Labels (10 Minutes)

# %%
labels = load_obj('labels')
if (labels is None or
    RE_RUN_CELLS):
    labeler = trane.Labeler()
    entity_to_data_dict = trane.df_group_by_entity_id(merged_df, entity_id_column)
    training_cutoff_time = datetime.date(2012, 1, 1)
    label_cutoff_time = datetime.date(2015, 1, 1)
    #First date: 2007-06-12
    #Last date: 2017-12-10
    entity_to_data_and_cutoff_dict = trane.ConstantCutoffTime(
                                        training_cutoff_time, label_cutoff_time
                                    ).generate_cutoffs(entity_to_data_dict, time_column)
    labels = labeler.execute(entity_to_data_and_cutoff_dict, prediction_problems_filename)
    
    save_obj(labels, 'labels')

# %% [markdown]
# ## Deep Feature Synthesis with Feature Tools (3 Minutes)

# %%
for idx, problem in enumerate(problems):
    print(idx)
    print(problem)
# Out:
# 0
# AllFilterOp(user_id)->IdentityRowOp(stars)->IdentityTransformationOp(stars)->FirstAggregationOp(stars)
# 1
# AllFilterOp(user_id)->GreaterRowOp(stars)->IdentityTransformationOp(stars)->FirstAggregationOp(stars)
# 2
# AllFilterOp(user_id)->EqRowOp(stars)->IdentityTransformationOp(stars)->FirstAggregationOp(stars)
# 3
# AllFilterOp(user_id)->NeqRowOp(stars)->IdentityTransformationOp(stars)->FirstAggregationOp(stars)
# 4
# AllFilterOp(user_id)->LessRowOp(stars)->IdentityTransformationOp(stars)->FirstAggregationOp(stars)
# 5
# AllFilterOp(user_id)->ExpRowOp(stars)->IdentityTransformationOp(stars)->FirstAggregationOp(stars)
# 6
# AllFilterOp(user_id)->IdentityRowOp(stars)->DiffTransformationOp(stars)->FirstAggregationOp(stars)
# 7
# AllFilterOp(user_id)->ExpRowOp(stars)->DiffTransformationOp(stars)->FirstAggregationOp(stars)
# 8
# AllFilterOp(user_id)->IdentityRowOp(stars)->ObjectFrequencyTransformationOp(stars)->FirstAggregationOp(stars)
# 9
# AllFilterOp(user_id)->GreaterRowOp(stars)->ObjectFrequencyTransformationOp(stars)->FirstAggregationOp(stars)
# 10
# AllFilterOp(user_id)->EqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->FirstAggregationOp(stars)
# 11
# AllFilterOp(user_id)->NeqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->FirstAggregationOp(stars)
# 12
# AllFilterOp(user_id)->LessRowOp(stars)->ObjectFrequencyTransformationOp(stars)->FirstAggregationOp(stars)
# 13
# AllFilterOp(user_id)->ExpRowOp(stars)->ObjectFrequencyTransformationOp(stars)->FirstAggregationOp(stars)
# 14
# AllFilterOp(user_id)->IdentityRowOp(stars)->IdentityTransformationOp(stars)->CountAggregationOp(stars)
# 15
# AllFilterOp(user_id)->GreaterRowOp(stars)->IdentityTransformationOp(stars)->CountAggregationOp(stars)
# 16
# AllFilterOp(user_id)->EqRowOp(stars)->IdentityTransformationOp(stars)->CountAggregationOp(stars)
# 17
# AllFilterOp(user_id)->NeqRowOp(stars)->IdentityTransformationOp(stars)->CountAggregationOp(stars)
# 18
# AllFilterOp(user_id)->LessRowOp(stars)->IdentityTransformationOp(stars)->CountAggregationOp(stars)
# 19
# AllFilterOp(user_id)->ExpRowOp(stars)->IdentityTransformationOp(stars)->CountAggregationOp(stars)
# 20
# AllFilterOp(user_id)->IdentityRowOp(stars)->DiffTransformationOp(stars)->CountAggregationOp(stars)
# 21
# AllFilterOp(user_id)->ExpRowOp(stars)->DiffTransformationOp(stars)->CountAggregationOp(stars)
# 22
# AllFilterOp(user_id)->IdentityRowOp(stars)->ObjectFrequencyTransformationOp(stars)->CountAggregationOp(stars)
# 23
# AllFilterOp(user_id)->GreaterRowOp(stars)->ObjectFrequencyTransformationOp(stars)->CountAggregationOp(stars)
# 24
# AllFilterOp(user_id)->EqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->CountAggregationOp(stars)
# 25
# AllFilterOp(user_id)->NeqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->CountAggregationOp(stars)
# 26
# AllFilterOp(user_id)->LessRowOp(stars)->ObjectFrequencyTransformationOp(stars)->CountAggregationOp(stars)
# 27
# AllFilterOp(user_id)->ExpRowOp(stars)->ObjectFrequencyTransformationOp(stars)->CountAggregationOp(stars)
# 28
# AllFilterOp(user_id)->IdentityRowOp(stars)->IdentityTransformationOp(stars)->SumAggregationOp(stars)
# 29
# AllFilterOp(user_id)->GreaterRowOp(stars)->IdentityTransformationOp(stars)->SumAggregationOp(stars)
# 30
# AllFilterOp(user_id)->EqRowOp(stars)->IdentityTransformationOp(stars)->SumAggregationOp(stars)
# 31
# AllFilterOp(user_id)->NeqRowOp(stars)->IdentityTransformationOp(stars)->SumAggregationOp(stars)
# 32
# AllFilterOp(user_id)->LessRowOp(stars)->IdentityTransformationOp(stars)->SumAggregationOp(stars)
# 33
# AllFilterOp(user_id)->ExpRowOp(stars)->IdentityTransformationOp(stars)->SumAggregationOp(stars)
# 34
# AllFilterOp(user_id)->IdentityRowOp(stars)->DiffTransformationOp(stars)->SumAggregationOp(stars)
# 35
# AllFilterOp(user_id)->ExpRowOp(stars)->DiffTransformationOp(stars)->SumAggregationOp(stars)
# 36
# AllFilterOp(user_id)->IdentityRowOp(stars)->ObjectFrequencyTransformationOp(stars)->SumAggregationOp(stars)
# 37
# AllFilterOp(user_id)->GreaterRowOp(stars)->ObjectFrequencyTransformationOp(stars)->SumAggregationOp(stars)
# 38
# AllFilterOp(user_id)->EqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->SumAggregationOp(stars)
# 39
# AllFilterOp(user_id)->NeqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->SumAggregationOp(stars)
# 40
# AllFilterOp(user_id)->LessRowOp(stars)->ObjectFrequencyTransformationOp(stars)->SumAggregationOp(stars)
# 41
# AllFilterOp(user_id)->ExpRowOp(stars)->ObjectFrequencyTransformationOp(stars)->SumAggregationOp(stars)
# 42
# AllFilterOp(user_id)->IdentityRowOp(stars)->IdentityTransformationOp(stars)->LastAggregationOp(stars)
# 43
# AllFilterOp(user_id)->GreaterRowOp(stars)->IdentityTransformationOp(stars)->LastAggregationOp(stars)
# 44
# AllFilterOp(user_id)->EqRowOp(stars)->IdentityTransformationOp(stars)->LastAggregationOp(stars)
# 45
# AllFilterOp(user_id)->NeqRowOp(stars)->IdentityTransformationOp(stars)->LastAggregationOp(stars)
# 46
# AllFilterOp(user_id)->LessRowOp(stars)->IdentityTransformationOp(stars)->LastAggregationOp(stars)
# 47
# AllFilterOp(user_id)->ExpRowOp(stars)->IdentityTransformationOp(stars)->LastAggregationOp(stars)
# 48
# AllFilterOp(user_id)->IdentityRowOp(stars)->DiffTransformationOp(stars)->LastAggregationOp(stars)
# 49
# AllFilterOp(user_id)->ExpRowOp(stars)->DiffTransformationOp(stars)->LastAggregationOp(stars)
# 50
# AllFilterOp(user_id)->IdentityRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LastAggregationOp(stars)
# 51
# AllFilterOp(user_id)->GreaterRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LastAggregationOp(stars)
# 52
# AllFilterOp(user_id)->EqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LastAggregationOp(stars)
# 53
# AllFilterOp(user_id)->NeqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LastAggregationOp(stars)
# 54
# AllFilterOp(user_id)->LessRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LastAggregationOp(stars)
# 55
# AllFilterOp(user_id)->ExpRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LastAggregationOp(stars)
# 56
# AllFilterOp(user_id)->IdentityRowOp(stars)->IdentityTransformationOp(stars)->LMFAggregationOp(stars)
# 57
# AllFilterOp(user_id)->ExpRowOp(stars)->IdentityTransformationOp(stars)->LMFAggregationOp(stars)
# 58
# AllFilterOp(user_id)->IdentityRowOp(stars)->DiffTransformationOp(stars)->LMFAggregationOp(stars)
# 59
# AllFilterOp(user_id)->ExpRowOp(stars)->DiffTransformationOp(stars)->LMFAggregationOp(stars)
# 60
# AllFilterOp(user_id)->IdentityRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LMFAggregationOp(stars)
# 61
# AllFilterOp(user_id)->GreaterRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LMFAggregationOp(stars)
# 62
# AllFilterOp(user_id)->EqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LMFAggregationOp(stars)
# 63
# AllFilterOp(user_id)->NeqRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LMFAggregationOp(stars)
# 64
# AllFilterOp(user_id)->LessRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LMFAggregationOp(stars)
# 65
# AllFilterOp(user_id)->ExpRowOp(stars)->ObjectFrequencyTransformationOp(stars)->LMFAggregationOp(stars)

# %%
training_features_matrix = load_obj('training_features_matrix')
test_features_matrix = load_obj('test_features_matrix')

if (training_features_matrix is None or
   test_features_matrix is None or
   RE_RUN_CELLS):
    entities = {
        "business": (sampled_yelp_business_df, "business_id"),
        "reviews": (sampled_yelp_review_df, "review_id"),
        "users": (sampled_yelp_user_df, "user_id"),
        "checkins": (sampled_yelp_checkin_df, "checkin_id")
    }
    relationships = [
        ("business", "business_id", "reviews", "business_id"),
        ("users", "user_id", "reviews", "user_id"),
        ("business", "business_id", "checkins", "business_id")
    ]

    #----FEATURES FOR TRAINING----#
    training_features_cutoff_times = pd.DataFrame([[_, training_cutoff_time] for _ in sampled_business_ids], columns = ['business_id', 'cutoff_time'])

    training_features_matrix, training_feature_definitions = ft.dfs(entities = entities,
        relationships = relationships,
        target_entity = "business",
        cutoff_time = training_features_cutoff_times)
    training_features_matrix, training_features = ft.encode_features(training_features_matrix, training_feature_definitions)

    #----FEATURES FOR TEST----#
    test_features_cutoff_times = pd.DataFrame([[_, label_cutoff_time] for _ in sampled_business_ids], columns = ['business_id', 'cutoff_time'])

    test_features_matrix, test_feature_definitions = ft.dfs(entities = entities,
        relationships = relationships,
        target_entity = "business",
        cutoff_time = test_features_cutoff_times)
    test_features_matrix, test_features = ft.encode_features(test_features_matrix, test_feature_definitions)

    save_obj(training_features_matrix, 'training_features_matrix')
    save_obj(test_features_matrix, 'test_features_matrix')

# %%
training_features_matrix
# Out:
#                         name = "McDonald's"  name = "Walmart Supercenter"  \
# business_id
# -A9sm-E6uQxWTJ_MuyOzFw                    0                             0
# -Bdw-5H5C4AYSMGnAvmnzw                    0                             0
# -BxWyEIQ6wypT-37MzZizQ                    0                             0
# -IcHkc7uWC8dHGlAOK4sJw                    0                             0
# -P8dGzSVhJi-5oZ-8U2y0w                    0                             0
# -Ucy8i4uc_OzN8y5fkGVaQ                    0                             0
# -Y0HN99LWf43NYQAx0T5aQ                    0                             0
# -cBQKodqi77Q0vk-9iDvQA                    0                             0
# 0-yj2jtzLUHG2b7PpEHyog                   ...
# 07F0eE_JHkH4Op0vpR_v4A                   ...
# 0AQnRQw34IQW9-1gJkYnMA                   ...
# 0H8PL4trSvZFYgPpvSOCjQ                   ...
# 0NmTwqYEQiKErDv4a55obg                   ...
# 0NoHJtug9xefI2OnsANaMA                   ...
# 0QzCeORfF8EY34UODWRV9A                   ...
# 0Rni7ocMC_Lg2UH0lDeKMQ                   ...
# 0TBTV3q6QXCn9vNhy3Xi2w                   ...
# 0U-1Wkl7y-wv39qM6WKL_w                   ...
# 0URIvKxCNT-AVgtdYFAX8w                   ...
# 0W4lkclzZThpx3V65bVgig                   ...
# 0WrhcwoAeDn2BcyUrZOkiw                   ...
# ...                                      ...
# yVLbAdSQQURBNWsJIxzmfw                   ...
# yXvyFDIdJTM0kLGSe7VYAw                   ...
# yZnEwqTGpkrj_mga5zeZmQ                   ...
# yaViddk9vxi-7p8DnjoClw                   ...
# yfxDa8RFOvJPQh0rNtakHA                   ...
# ygJshif4VuxL1ijnRJnuYA                   ...
# ygZSfAsnlztdeWZOlJA2Ug                   ...
# yhgUyctWczUN13MinNgZ3w                   ...
# ym5FOqL6tGbgynzwKMHZuw                   ...
# yuFdJdrnfMp3cfXVwTXjjA                   ...
# yvJqxVTO_qwRGLMtUrqzQw                   ...
# yvqcZrHixuf_oIUW83xUcQ                   ...
# yymNrvk1cioG5Bn5lWH2QQ                   ...
# yz2EimDE7bBvq6b4mDe_zg                   ...
# yzmvsG3Vo-2_F3_0wHzJdA                   ...
# z-m0Dj_ea_SQra2kYds1Dw                   ...
# z0cjTX7o6gJsXm2hWHaKGw                   ...
# z6-reuC5BYf_Rth9gMBfgQ                   ...
# z8oIoCT1cXz7gZP5GeU5OA                   ...
# zJCbSgXWFWwvKiIRFFuiTA                   ...
# zKqWjDZHo-lk7_E3hHkORg                   ...
# zRqi6L1u-YmmVAHjeUbGMQ                   ...
# zUpJKj7qFbMIeP_qDgjegA                   ...
# zaJkOJU0EtsUyjjP-z59ow                   ...
# zgQHtqX0gqMw1nlBZl2VnQ                   ...
# zkU-WMio8g6dpRJ2Y2xqvQ                   ...
# zrMGL9riavdJR4olXaACOQ                   ...
# zvVBDfGuo0ePnMehMCfWrg                   ...
# zw9_mqWBn1QCfZg88w0Exg                   ...
# zxJlg4XCHNoFy78WZPv89w                   ...
#
#                         NUM_UNIQUE(checkins.MONTH(hour))  \
# business_id
# -A9sm-E6uQxWTJ_MuyOzFw                               1.0
# -Bdw-5H5C4AYSMGnAvmnzw                               1.0
# -BxWyEIQ6wypT-37MzZizQ                               1.0
# -IcHkc7uWC8dHGlAOK4sJw                               1.0
# -P8dGzSVhJi-5oZ-8U2y0w                               1.0
# -Ucy8i4uc_OzN8y5fkGVaQ                               1.0
# -Y0HN99LWf43NYQAx0T5aQ                               1.0
# -cBQKodqi77Q0vk-9iDvQA                               1.0
# -dy1d0ohs4D8qkJoenHNJA                               1.0
# -ed0Yc9on37RoIoG2ZgxBA                               1.0
# -hn7E7b3VwRjwhNEDgmGIQ                               1.0
# -ipc5f0XiXwH3hbNnro54Q                               1.0
# -jGA3ADqqv0PyB7Mbo-Zsw                               1.0
# -sAr-LA9TsIdl37UjwBlvg                               1.0
# -tcJmqzfaeEnpFMAelB7bA                               1.0
# -yXkMzPPQ2PvzIC-NrH-Sg                               1.0
# -zCngfAQdoS5Nfr_-G0N5w                               1.0
# 0-yj2jtzLUHG2b7PpEHyog                               1.0
# 07F0eE_JHkH4Op0vpR_v4A                               1.0
# 0AQnRQw34IQW9-1gJkYnMA                               1.0
# 0H8PL4trSvZFYgPpvSOCjQ                               1.0
# 0NmTwqYEQiKErDv4a55obg                               1.0
# 0NoHJtug9xefI2OnsANaMA                               1.0
# 0QzCeORfF8EY34UODWRV9A                               1.0
# 0Rni7ocMC_Lg2UH0lDeKMQ                               1.0
# 0TBTV3q6QXCn9vNhy3Xi2w                               1.0
# 0U-1Wkl7y-wv39qM6WKL_w                               1.0
# 0URIvKxCNT-AVgtdYFAX8w                               1.0
# 0W4lkclzZThpx3V65bVgig                               1.0
# 0WrhcwoAeDn2BcyUrZOkiw                               1.0
# ...                                                  ...
# yVLbAdSQQURBNWsJIxzmfw                               NaN
# yXvyFDIdJTM0kLGSe7VYAw                               NaN
# yZnEwqTGpkrj_mga5zeZmQ                               1.0
# yaViddk9vxi-7p8DnjoClw                               1.0
# yfxDa8RFOvJPQh0rNtakHA                               1.0
# ygJshif4VuxL1ijnRJnuYA                               1.0
# ygZSfAsnlztdeWZOlJA2Ug                               1.0
# yhgUyctWczUN13MinNgZ3w                               1.0
# ym5FOqL6tGbgynzwKMHZuw                               1.0
# yuFdJdrnfMp3cfXVwTXjjA                               1.0
# yvJqxVTO_qwRGLMtUrqzQw                               1.0
# yvqcZrHixuf_oIUW83xUcQ                               1.0
# yymNrvk1cioG5Bn5lWH2QQ                               1.0
# yz2EimDE7bBvq6b4mDe_zg                               1.0
# yzmvsG3Vo-2_F3_0wHzJdA                               1.0
# z-m0Dj_ea_SQra2kYds1Dw                               1.0
# z0cjTX7o6gJsXm2hWHaKGw                               1.0
# z6-reuC5BYf_Rth9gMBfgQ                               1.0
# z8oIoCT1cXz7gZP5GeU5OA                               1.0
# zJCbSgXWFWwvKiIRFFuiTA                               1.0
# zKqWjDZHo-lk7_E3hHkORg                               1.0
# zRqi6L1u-YmmVAHjeUbGMQ                               1.0
# zUpJKj7qFbMIeP_qDgjegA                               1.0
# zaJkOJU0EtsUyjjP-z59ow                               1.0
# zgQHtqX0gqMw1nlBZl2VnQ                               1.0
# zkU-WMio8g6dpRJ2Y2xqvQ                               1.0
# zrMGL9riavdJR4olXaACOQ                               1.0
# zvVBDfGuo0ePnMehMCfWrg                               1.0
# zw9_mqWBn1QCfZg88w0Exg                               1.0
# zxJlg4XCHNoFy78WZPv89w                               1.0
#
#                         NUM_UNIQUE(checkins.WEEKDAY(hour))  \
# business_id
# -A9sm-E6uQxWTJ_MuyOzFw                
# yz2EimDE7bBvq6b4mDe_zg                                   1
# yzmvsG3Vo-2_F3_0wHzJdA                                   1
# z-m0Dj_ea_SQra2kYds1Dw                                   1
# z0cjTX7o6gJsXm2hWHaKGw                                   1
# z6-reuC5BYf_Rth9gMBfgQ                                   1
# z8oIoCT1cXz7gZP5GeU5OA                                   1
# zJCbSgXWFWwvKiIRFFuiTA                                   1
# zKqWjDZHo-lk7_E3hHkORg                                   1
# zRqi6L1u-YmmVAHjeUbGMQ                                   1
# zUpJKj7qFbMIeP_qDgjegA                                   1
# zaJkOJU0EtsUyjjP-z59ow                                   1
# zgQHtqX0gqMw1nlBZl2VnQ                                   1
# zkU-WMio8g6dpRJ2Y2xqvQ                                   1
# zrMGL9riavdJR4olXaACOQ                                   1
# zvVBDfGuo0ePnMehMCfWrg                                   1
# zw9_mqWBn1QCfZg88w0Exg                                   1
# zxJlg4XCHNoFy78WZPv89w                                   1
#
#                         MODE(checkins.YEAR(hour)) = unknown  \
# business_id
# -A9sm-E6uQxWTJ_MuyOzFw                                    0
# -Bdw-5H5C4AYSMGnAvmnzw                                    0
# -BxWyEIQ6wypT-37MzZizQ                                    0
# -IcHkc7uWC8dHGlAOK4sJw                                    0
# -P8dGzSVhJi-5oZ-8U2y0w                                    0
# -Ucy8i4uc_OzN8y5fkGVaQ                                    0
# -Y0HN99LWf43NYQAx0T5aQ                                    0
# -cBQKodqi77Q0vk-9iDvQA                                    0
# -dy1d0ohs4D8qkJoenHNJA                                    0
# -ed0Yc9on37RoIoG2ZgxBA                                    0
# -hn7E7b3VwRjwhNEDgmGIQ                                    0
# -ipc5f0XiXwH3hbNnro54Q                                    0
# -jGA3ADqqv0PyB7Mbo-Zsw                                    0
# -sAr-LA9TsIdl37UjwBlvg                                    0
# -tcJmqzfaeEnpFMAelB7bA                                    0
# -yXkMzPPQ2PvzIC-NrH-Sg                                    0
# -zCngfAQdoS5Nfr_-G0N5w                                    0
# 0-yj2jtzLUHG2b7PpEHyog                                    0
# 07F0eE_JHkH4Op0vpR_v4A                                    0
# 0AQnRQw34IQW9-1gJkYnMA                                    0
# 0H8PL4trSvZFYgPpvSOCjQ                                    0
# 0NmTwqYEQiKErDv4a55obg                                    0
# 0NoHJtug9xefI2OnsANaMA                                    0
# 0QzCeORfF8EY34UODWRV9A                                    0
# 0Rni7ocMC_Lg2UH0lDeKMQ                                    0
# 0TBTV3q6QXCn9vNhy3Xi2w                                    0
# 0U-1Wkl7y-wv39qM6WKL_w                                    0
# 0URIvKxCNT-AVgtdYFAX8w                                    0
# 0W4lkclzZThpx3V65bVgig                                    0
# ...
# zw9_mqWBn1QCfZg88w0Exg                                    0
# zxJlg4XCHNoFy78WZPv89w                                    0
#
#                         MODE(checkins.MONTH(hour)) = 4.0  \
# business_id
# -A9sm-E6uQxWTJ_MuyOzFw                
# z-m0Dj_ea_SQra2kYds1Dw                                       0
# z0cjTX7o6gJsXm2hWHaKGw                                       0
# z6-reuC5BYf_Rth9gMBfgQ                                       0
# z8oIoCT1cXz7gZP5GeU5OA                                       0
# zJCbSgXWFWwvKiIRFFuiTA                                       0
# zKqWjDZHo-lk7_E3hHkORg                                       0
# zRqi6L1u-YmmVAHjeUbGMQ                                       0
# zUpJKj7qFbMIeP_qDgjegA                                       0
# zaJkOJU0EtsUyjjP-z59ow                                       0
# zgQHtqX0gqMw1nlBZl2VnQ                                       0
# zkU-WMio8g6dpRJ2Y2xqvQ                                       0
# zrMGL9riavdJR4olXaACOQ                                       0
# zvVBDfGuo0ePnMehMCfWrg                                       0
# zw9_mqWBn1QCfZg88w0Exg                                       0
# zxJlg4XCHNoFy78WZPv89w                                       0
#
# [974 rows x 328 columns]

# %% [markdown]
# ## Logistic Regression Fitting and Prediciton

# %%
logistic = linear_model.LogisticRegression()
PROBLEM_IDX_WITH_OOB_ERROR = 14


for idx, label in enumerate(labels):
# for idx in [PROBLEM_IDX_WITH_OOB_ERROR]:
    label = labels[idx]
    print("Training logistic regression on prediction problem {}".format(idx))
    label = label.dropna()
    training_features = training_features_matrix[training_features_matrix.index.isin(label.business_id)]
    training_labels = list(label['problem_label_excluding_data_post_label_cutoff_time'])
    
    test_features = test_features_matrix[test_features_matrix.index.isin(label.business_id)]
    test_labels = list(label['problem_label_all_data'])
    try:
        logistic.fit(training_features, training_labels)
    except Exception as e:
        print("ERROR: {}".format(e))
#         print("label: \n{}".format(label))
        continue
    
    predicted_labels = logistic.predict(test_features)
    predicted_probabilities = logistic.predict_proba(test_features)
    
    accuracy = accuracy_score(test_labels, predicted_labels)
#     print("Classifier Accuracy: {0:.4f}".format(accuracy))

    accuracy_no_prediction = accuracy_score(training_labels, predicted_labels)
#     print("Baseline Accuracy Metric: {0:.4f}, based on using training_labels as the prediction".format(accuracy))

    try:
        skplt.metrics.plot_roc_curve(test_labels, predicted_probabilities)
    except Exception as e:
#         print("Test labels: {}".format(test_labels['problem_label_excluding_data_post_label_cutoff_time']))
#         print("Predicted probabilities: {}".format(predicted_probabilities))
        print(len(test_labels))
        print(len(predicted_probabilities.shape))
        print("ERROR: {}".format(e))
        continue
    plt.show()
# Out:
# Training logistic regression on prediction problem 0
# Training logistic regression on prediction problem 1
# Training logistic regression on prediction problem 2
# Training logistic regression on prediction problem 3
# Training logistic regression on prediction problem 4
# Training logistic regression on prediction problem 5
# ERROR: Unknown label type: 'continuous'
# Training logistic regression on prediction problem 6
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0
# Training logistic regression on prediction problem 7
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0
# Training logistic regression on prediction problem 8
# Training logistic regression on prediction problem 9
# Training logistic regression on prediction problem 10
# Training logistic regression on prediction problem 11
# Training logistic regression on prediction problem 12
# Training logistic regression on prediction problem 13
# Training logistic regression on prediction problem 14
# 639
# 2
# ERROR: index 171 is out of bounds for axis 1 with size 171
# Training logistic regression on prediction problem 15
# 639
# 2
# ERROR: index 171 is out of bounds for axis 1 with size 171
# Training logistic regression on prediction problem 16
# 639
# 2
# ERROR: index 171 is out of bounds for axis 1 with size 171
# Training logistic regression on prediction problem 17
# 639
# 2
# ERROR: index 171 is out of bounds for axis 1 with size 171
# Training logistic regression on prediction problem 18
# 639
# 2
# ERROR: index 171 is out of bounds for axis 1 with size 171
# Training logistic regression on prediction problem 19
# 639
# 2
# ERROR: index 171 is out of bounds for axis 1 with size 171
# Training logistic regression on prediction problem 20
# 639
# 2
# ERROR: index 171 is out of bounds for axis 1 with size 171
# Training logistic regression on prediction problem 21
# 639
# 2
# ERROR: index 171 is out of bounds for axis 1 with size 171
# Training logistic regression on prediction problem 22
# Training logistic regression on prediction problem 23
# Training logistic regression on prediction problem 24
# Training logistic regression on prediction problem 25
# Training logistic regression on prediction problem 26
# Training logistic regression on prediction problem 27
# Training logistic regression on prediction problem 28
# 639
# 2
# ERROR: index 316 is out of bounds for axis 1 with size 316
# Training logistic regression on prediction problem 29
# 639
# 2
# ERROR: index 148 is out of bounds for axis 1 with size 148
# Training logistic regression on prediction problem 30
# 639
# 2
# ERROR: index 126 is out of bounds for axis 1 with size 126
# Training logistic regression on prediction problem 31
# 639
# 2
# ERROR: index 153 is out of bounds for axis 1 with size 153
# Training logistic regression on prediction problem 32
# 639
# 2
# ERROR: index 135 is out of bounds for axis 1 with size 135
# Training logistic regression on prediction problem 33
# ERROR: Unknown label type: 'continuous'
# Training logistic regression on prediction problem 34
# Training logistic regression on prediction problem 35
# ERROR: Unknown label type: 'continuous'
# Training logistic regression on prediction problem 36
# Training logistic regression on prediction problem 37
# Training logistic regression on prediction problem 38
# Training logistic regression on prediction problem 39
# 639
# 2
# ERROR: index 2 is out of bounds for axis 1 with size 2
# Training logistic regression on prediction problem 40
# Training logistic regression on prediction problem 41
# Training logistic regression on prediction problem 42
# Training logistic regression on prediction problem 43
# Training logistic regression on prediction problem 44
# Training logistic regression on prediction problem 45
# Training logistic regression on prediction problem 46
# Training logistic regression on prediction problem 47
# ERROR: Unknown label type: 'continuous'
# Training logistic regression on prediction problem 48
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0
# Training logistic regression on prediction problem 49
# ERROR: Unknown label type: 'continuous'
# Training logistic regression on prediction problem 50
# Training logistic regression on prediction problem 51
# Training logistic regression on prediction problem 52
# Training logistic regression on prediction problem 53
# Training logistic regression on prediction problem 54
# Training logistic regression on prediction problem 55
# Training logistic regression on prediction problem 56
# Training logistic regression on prediction problem 57
# ERROR: Unknown label type: 'continuous'
# Training logistic regression on prediction problem 58
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0
# Training logistic regression on prediction problem 59
# ERROR: Unknown label type: 'continuous'
# Training logistic regression on prediction problem 60
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0
# Training logistic regression on prediction problem 61
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0
# Training logistic regression on prediction problem 62
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0
# Training logistic regression on prediction problem 63
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0
# Training logistic regression on prediction problem 64
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0
# Training logistic regression on prediction problem 65
# ERROR: This solver needs samples of at least 2 classes in the data, but the data contains only one class: 0.0

# %%
logistic = linear_model.LogisticRegression()

PROBLEM_IDX_WITH_OOB_ERROR = 14
# PROBLEM_IDX_WITH_NO_ERROR = 13

# idx = PROBLEM_IDX_WITH_NO_ERROR
# label = labels[idx]
# print("Training logistic regression on prediction problem {}".format(idx))
# label = label.dropna()
# training_features = training_features_matrix[training_features_matrix.index.isin(label.business_id)]
# training_labels = list(label['problem_label_excluding_data_post_label_cutoff_time'])

# test_features = test_features_matrix[test_features_matrix.index.isin(label.business_id)]
# test_labels = list(label['problem_label_all_data'])
# logistic.fit(training_features, training_labels)

# predicted_labels = logistic.predict(test_features)
# predicted_probabilities = logistic.predict_proba(test_features)
# try:
#     skplt.metrics.plot_roc_curve(test_labels, predicted_probabilities)
#     print("# of test labels: {}".format(len(test_labels)))
#     print("# of unique test labels: {}".format(len(np.unique(test_labels))))
#     print(predicted_probabilities.shape)
# except Exception as e:
#     print(e)
    
idx = PROBLEM_IDX_WITH_OOB_ERROR
label = labels[idx]

#Note: modifying the problem so it's a classification, not a regression, by using a GreaterRowOp with threshold:50.
label['problem_label_excluding_data_post_label_cutoff_time'] = label['problem_label_excluding_data_post_label_cutoff_time'] > 50
label['problem_label_all_data'] = label['problem_label_all_data'] > 50


print("Training logistic regression on prediction problem {}".format(idx))
label = label.dropna()
training_features = training_features_matrix[training_features_matrix.index.isin(label.business_id)]
training_labels = list(label['problem_label_excluding_data_post_label_cutoff_time'])

test_features = test_features_matrix[test_features_matrix.index.isin(label.business_id)]
test_labels = list(label['problem_label_all_data'])
logistic.fit(training_features, training_labels)

predicted_labels = logistic.predict(test_features)
predicted_probabilities = logistic.predict_proba(test_features)

indices = find_missing_label_indices(training_labels, test_labels)
predicted_probabilities = format_predicted_proba(predicted_probabilities, indices)

try:
    skplt.metrics.plot_roc_curve(
                                test_labels, predicted_probabilities,
                                classes = np.unique(training_labels + test_labels)
                                )
except Exception as e:
    print("# of test labels: {}".format(len(test_labels)))
    print("# of unique test labels: {}".format(len(np.unique(test_labels))))
    print(predicted_probabilities.shape)
    print("ERROR: {}".format(e))
plt.show()
# Out:
# Training logistic regression on prediction problem 14

# %%
def find_missing_label_indices(train_labels, test_labels):
    """
    Finds the indices where columns of all zeros should be inserted to predicted_proba.
    
    Args
    ----------
    train_labels: the labels seen in training
    test_labels: the labels seen in testing
    
    Returns
    ----------
    indices_to_add: list of indices where a column should be inserted before each index
        to ensure all labels seen in test have a corresponding probability.
    """
    if set(test_labels).issubset(train_labels):
        return []
    train_classes = (np.unique(np.array(train_labels)))
    test_classes = (np.unique(np.array(test_labels)))
    values = np.setdiff1d(test_classes, train_classes)
    indices_to_add = [np.where(test_classes == value)[0][0] for value in values]
    return indices_to_add
def format_predicted_proba(array, indices):
    """
    Insert the columns of all zeros into array at indices
    
    Args
    ----------
    array: array to perform insertions on
    indices: the indices before which a column of zeros should be inserted
    
    Returns
    ----------
    array: updated array with columns of all zeros inserted
    """
    if indices is None:
        return array
    indices_before_len = [idx for idx in indices if idx <= array.shape[1]]
    partially_filled_array = np.insert(array, indices_before_len, 0, axis = 1)
    num_indices_after_len = len(indices) - len(indices_before_len)
    arr_to_append = np.zeros((array.shape[0], num_indices_after_len))
    return np.append(partially_filled_array, arr_to_append, axis = 1)

# %%
label
# Out:
#                 business_id  \
# 0    -A9sm-E6uQxWTJ_MuyOzFw
# 1    -Bdw-5H5C4AYSMGnAvmnzw
# 2    -BxWyEIQ6wypT-37MzZizQ
# 5    -Ucy8i4uc_OzN8y5fkGVaQ
# 6    -Y0HN99LWf43NYQAx0T5aQ
# 7    -cBQKodqi77Q0vk-9iDvQA
# 8    -dy1d0ohs4D8qkJoenHNJA
# 10   -hn7E7b3VwRjwhNEDgmGIQ
# 12   -jGA3ADqqv0PyB7Mbo-Zsw
# 13   -sAr-LA9TsIdl37UjwBlvg
# 14   -tcJmqzfaeEnpFMAelB7bA
# 15   -yXkMzPPQ2PvzIC-NrH-Sg
# 16   -zCngfAQdoS5Nfr_-G0N5w
# 17   0-yj2jtzLUHG2b7PpEHyog
# 18   07F0eE_JHkH4Op0vpR_v4A
# 19   0AQnRQw34IQW9-1gJkYnMA
# 20   0H8PL4trSvZFYgPpvSOCjQ
# 21   0NmTwqYEQiKErDv4a55obg
# 22   0NoHJtug9xefI2OnsANaMA
# 24   0Rni7ocMC_Lg2UH0lDeKMQ
# 25   0TBTV3q6QXCn9vNhy3Xi2w
# 26   0U-1Wkl7y-wv39qM6WKL_w
# 27   0URIvKxCNT-AVgtdYFAX8w
# 28   0W4lkclzZThpx3V65bVgig
# 29   0WrhcwoAeDn2BcyUrZOkiw
# 32   0g7Pr8OWl_t_7DUeYJrrGw
# 34   0uR48n5SYcLE_DLcjONZPg
# 35   0yH5_sluR0BmgaxUyJUj1A
# 38   1Lbq92b6B9z1FYk5mS2R9Q
# 39   1VOJtXuhsDvF5IQwJ-Pp2w
# ..                      ...
# 906  wOIh5bvOsSv1zcRrX6A8Lw
# 909  wSojc-y-d7MWiGWdy8deCg
# 910  wWhq9cKLCrZHcp-ezp-hPQ
# 911  wcA-pfNAmxRJC9N2IcJX3w
# 912  wjW6YN9s-iDq7l9PcUsPZw
# 914  wvsadleYJavXp8u697GK6A
# 915  x5vSE0-NO_YSZtOnitLWuQ
# 916  x8C6vsv0JxupP1-s_ppl7g
# 917  x9HvTsA83c5r-muemxw_9A
# 918  xC1-8kKTeLkF85GZ9IfVow
# 921  xObQl57iTZrg8-hfMkMF6g
# 922  xVEtGucSRLk5pxxN0t4i6g
# 923  xm6OKOUnvpn58ejuY6-yQQ
# 926  xvIKjbhFydKRzrnibKuBDA
# 927  xw6G0T2VQZAtta6RcZoAOQ
# 928  y45zdBlXT0Mr0gEfYOzXlw
# 930  yQab5dxZzgBLTEHCw9V7_w
# 932  yaViddk9vxi-7p8DnjoClw
# 940  yvqcZrHixuf_oIUW83xUcQ
# 941  yymNrvk1cioG5Bn5lWH2QQ
# 944  z-m0Dj_ea_SQra2kYds1Dw
# 946  z6-reuC5BYf_Rth9gMBfgQ
# 947  z8oIoCT1cXz7gZP5GeU5OA
# 948  zJCbSgXWFWwvKiIRFFuiTA
# 951  zUpJKj7qFbMIeP_qDgjegA
# 952  zaJkOJU0EtsUyjjP-z59ow
# 953  zgQHtqX0gqMw1nlBZl2VnQ
# 955  zrMGL9riavdJR4olXaACOQ
# 956  zvVBDfGuo0ePnMehMCfWrg
# 958  zxJlg4XCHNoFy78WZPv89w
#
#      problem_label_excluding_data_post_label_cutoff_time  \
# 0                                                 10.0
# 1                                                 91.0
# 2                                                110.0
# 5                                                 96.0
# 6                                                106.0
# 7                                                111.0
# 8                                                  3.0
# 10                                                40.0
# 12                                                56.0
# 13                                               147.0
# 14                                                83.0
# 15                                                22.0
# 16                                                28.0
# 17                                                47.0
# 18                                                53.0
# 19                                               145.0
# 20                                                 1.0
# 21                                               134.0
# 22                                                78.0
# 24                                                62.0
# 25                                                97.0
# 26                                               107.0
# 27                                                74.0
# 28                                               138.0
# 29                                                84.0
# 32                                                 2.0
# 34                                                82.0
# 35                                                14.0
# 38                                               112.0
# 39                                                17.0
# ..                                                 ...
# 906                                               33.0
# 909                                               97.0
# 910                                              115.0
# 911                                               23.0
# 912                                               50.0
# 914                                               22.0
# 915                                               59.0
# 916                                               52.0
